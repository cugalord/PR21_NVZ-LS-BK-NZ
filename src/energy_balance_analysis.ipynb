# %% [markdown]
# # 3. Analiza energetske bilance
#
# **Pri tem vprašanju nas je zanimala analiza energetske bilance skozi leta in sprememba porabe energije glede na panogo.**

# %% [markdown]
# #### 3.1 Pregled podatkov v potrebnih podatkovnih množicah
#
# Najprej smo pregledali podatke v podatkovnih množicah, ki smo jih uporabljali. To smo naredili z izpisom glave podatkovnega okvirja.

# %%
from reading import data_extraction as de
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import misc_utils as mu

energy_balance = de.read('../data/Energetska bilanca.csv')
energy_use     = de.read('../data/Energetska poraba goriv, električne energije in toplotne energije po dejavnosti.csv')

mu.display_side_by_side(energy_balance.head(), energy_use.head(), titles=['Energetska bilanca', 'Energetska poraba'], suppres_scientific=True)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>Energetska bilanca</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>OSKRBA IN PORABA</th>
#       <th>2000 Trdna goriva</th>
#       <th>2000 Surova nafta</th>
#       <th>2000 Naftni proizvodi</th>
#       <th>2000 Zemeljski plin</th>
#       <th>2000 Nuklearna energija</th>
#       <th>2000 Hidro energija</th>
#       <th>2000 Geoterm., sončna itd.</th>
#       <th>2000 Obnovljivi viri in odpadki</th>
#       <th>2000 Električna energija</th>
#       <th>2000 Toplota</th>
#       <th>2000 Energetski viri-SKUPAJ</th>
#       <th>2001 Trdna goriva</th>
#       <th>2001 Surova nafta</th>
#       <th>2001 Naftni proizvodi</th>
#       <th>2001 Zemeljski plin</th>
#       <th>2001 Nuklearna energija</th>
#       <th>2001 Hidro energija</th>
#       <th>2001 Geoterm., sončna itd.</th>
# ...

# %% [markdown]
# Kot lahko vidimo, so podatkovne množice v precej neuporabni obliki, saj želimo, da so v stolpcih samo leta, ostali atributi pa so v posebnem stolpcu. Tak format želimo zato, da lahko podatke obdelujemo po časovnih obdobjih, brez da bi bilo potrebno manipuliranje imen stolpcev.

# %% [markdown]
# #### 3.2 Preoblikovanje podatkovnih množic
#
# Najprej smo se lotili preoblikovanja podatkovnih množic v format, ki je bolj primeren za našo uporabo.

# %%
# Get unique values of energy sources and years
balance_sources = list(dict.fromkeys([' '.join(col.split()[1:]) for col in energy_balance.columns[1:]]))
balance_years   = sorted(list(set([col.split()[0] for col in energy_balance.columns[1:]])))

# Create new dataframe
balance = pd.DataFrame()

# Add needed columns to dataframe
balance.insert(0, 'OSKRBA IN PORABA', '')
balance.insert(1, 'ENERGETSKI VIR', '')
count = 2
for year in balance_years:
    balance.insert(count, year, np.nan)
    count += 1

## Fill dataframe with data
# Add first two columns
for supply_and_usage in energy_balance['OSKRBA IN PORABA']:
    for source in balance_sources:
        balance.loc[len(balance.index)] = [supply_and_usage, source] + [np.nan] * len(balance_years)

# Add values from Energetska bilanca.csv
for col in energy_balance.columns[1:]:
    # Extract year and energy source from column name
    year   = col.split()[0]
    source = ' '.join(col.split()[1:])
    # Loop through all rows in dataframe and add value to appropriate cell
    for index, row in energy_balance.iterrows():
        if row[col] != '-' and row[col] != 'N':
            balance.loc[(balance['OSKRBA IN PORABA'] == row['OSKRBA IN PORABA']) & (balance['ENERGETSKI VIR'] == source), year] = row[col]


mu.display_side_by_side(balance.head())
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>OSKRBA IN PORABA</th>
#       <th>ENERGETSKI VIR</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Domača proizvodnja</td>
#       <td>Trdna goriva</td>
#       <td>46687.0</td>
#       <td>44314.0</td>
#       <td>48556.0</td>
#       <td>49576.0</td>
#       <td>50269.0</td>
# ...

# %%
# Get unique values of energy sources and years
use_sources = list(dict.fromkeys([' '.join(col.split()[7:]).capitalize() for col in energy_use.columns[1:]]))
use_years   = sorted(list(set([col.split()[0] for col in energy_use.columns[1:]])))

# Create new dataframe
use = pd.DataFrame()

# Add needed columns to dataframe
use.insert(0, 'PODROČJA IN PODPODROČJA DEJAVNOSTI', '')
use.insert(1, 'ENERGETSKI VIR', '')
count = 2
for year in use_years:
    use.insert(count, year, np.nan)
    count += 1	

## Fill dataframe with data
# Add first two columns
for field in energy_use['PODROČJA IN PODPODROČJA DEJAVNOSTI']:
    for source in use_sources:
        use.loc[len(use.index)] = [field, source] + [np.nan] * len(use_years)
        
# Add values from Energetska poraba goriv, električne energije in toplotne energije po dejavnosti.csv
for col in energy_use.columns[1:]:
    # Extract year and energy source from column name
    year   = col.split()[0]
    source = ' '.join(col.split()[7:]).capitalize()
    
    # Select only appropriate columns
    if ' '.join(col.split()[1:7]) == 'Vključno s porabo goriv za transformacijo':
        # Loop through all rows in dataframe and add value to appropriate cell
        for index, row in energy_use.iterrows():
            if row[col] != '-' and row[col] != 'N':
                use.loc[(use['PODROČJA IN PODPODROČJA DEJAVNOSTI'] == row['PODROČJA IN PODPODROČJA DEJAVNOSTI']) & (use['ENERGETSKI VIR'] == source), year] = row[col]
            
mu.display_side_by_side(use.head())
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PODROČJA IN PODPODROČJA DEJAVNOSTI</th>
#       <th>ENERGETSKI VIR</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SKUPAJ A, B, C, D, E, F</td>
#       <td>Električna energija</td>
#       <td>22992.0</td>
#       <td>18132.0</td>
#       <td>20001.0</td>
#       <td>21353.0</td>
#       <td>21561.0</td>
#       <td>21389.0</td>
#       <td>22011.0</td>
#       <td>22530.0</td>
#       <td>22651.0</td>
#       <td>23407.0</td>
#       <td>24320.0</td>
# ...

# %% [markdown]
# Podatkovne množice smo preoblikovali tako, da smo ustvarili nova podatkovna okvirja, katerima smo pripisali potrebne stolpce, nato pa smo v ustrezne celice vstavili vrednost iz originalnih podatkovnih množic. Tako smo dobili podatkovne okvirje, s katerimi je lažje delati (dostopati do vrednosti, analizirati vrednosti v času, itd.). V Energetsko porabo goriv smo vključili tudi porabo goriv za transformacijo, saj smo se tako lahko osredotočili tudi na področja energetike in oskrbe z vodo, prav tako pa smo tako imeli bolj popolne podatke.

# %% [markdown]
# #### 3.3 Analiza energetske bilance
#
# Pri tem podvprašanju smo analizirali energetsko bilanco skozi čas, bolj specifično, pogledali smo skupno končno porabo energetskih virov v letnih intervalih, analizirali smo porabo energentov po sektorjih, ki so se nam zdeli najbolj zanimivi, in analizirali uvoz/izvoz naftnih proizvodov, saj so najbolj porabljan energent.

# %%
# Create dictionary with energy sources
final_usage = mu.init_dict_based_on_column(balance, 'ENERGETSKI VIR')

# Fill dictionary
for year in balance.columns[2:]:
    for key in final_usage.keys():
        final_usage[key][year] = balance[year][balance['ENERGETSKI VIR'] == key][balance['OSKRBA IN PORABA'] == 'Končna poraba'].to_list()[0]

# Flatten internal dict
final_usage_f = mu.flatten_internal_dict(final_usage)

years = balance.columns[2:]

# Plot different energy sources
plt.figure(figsize=(20, 5))
plt.suptitle("Končna poraba energetskih virov", fontsize=20)
plt.xticks(rotation=90)
plt.ylabel("Poraba energenta (TJ)")
plt.grid()
for key, value in final_usage_f.items():
    if key != 'Energetski viri-SKUPAJ':
        plt.plot(years, value, label=key)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# Opazili smo, da vsi sektorji skupaj največ porabijo naftnih proizvodov, takoj za tem je električna energija, zemeljski plin ter obnovljivi viri. Posebej zanimiv je padec v porabi nekaterih energentov (naftni proizvodi, električna energija, zemeljski plin) v letu 2009, in močan padec v porabi naftnih proizvodov iz leta 2019 na 2020.
#
# Predvidevamo, da je do padca porabe naftnih proizvodov leta 2020 prišlo zaradi prvega vala COVID-19, saj je bila država zaprta, in zaradi tega ljudje niso vozili, tovarne niso obratovale, itd.
#
# Vpadanje porabe nekaterih energetskih virov leta 2009 potrjuje tudi [Direktorat za energijo, str. 9](http://www.energetika-portal.si/fileadmin/dokumenti/publikacije/energija_slo/evs_2009.pdf), ki pravi, da je bila oskrba z energijo leta 2009 v primerjavi z 2008 manjša za 8.5%, iz domačih virov je bilo pridobljeno 0.3% manj energije, uvoz pa je bil manjši za celih 12.1%. Predvidevamo, da je do tega prišlo zaradi globalne krize leta 2009, ki je močno udarila na mnoge sektorje, ki porabljajo navedene energente.

# %% [markdown]
# ##### 3.3.1 Analiza porabe po nekaterih sektorjih (kmetijski, prometni, neenergetski)

# %%
# Create dicts of energy sources and their usages for each sector (farming, traffic, non-energy) in balance dataframe
balance_farming    = mu.init_dict_based_on_column(balance, 'ENERGETSKI VIR')
balance_traffic    = mu.init_dict_based_on_column(balance, 'ENERGETSKI VIR')
balance_non_energy = mu.init_dict_based_on_column(balance, 'ENERGETSKI VIR')

# Fill dicts with data
for year in balance.columns[2:]:
    for key in balance_farming.keys():
        balance_farming[key][year]    = balance[year][balance['ENERGETSKI VIR'] == key][balance['OSKRBA IN PORABA'] == 'Končna poraba-Kmetijstvo in gozdarstvo'].to_list()[0]
        balance_traffic[key][year]    = balance[year][balance['ENERGETSKI VIR'] == key][balance['OSKRBA IN PORABA'] == 'Končna poraba-Promet'].to_list()[0]
        balance_non_energy[key][year] = balance[year][balance['ENERGETSKI VIR'] == key][balance['OSKRBA IN PORABA'] == 'Končna poraba-Neenergetska raba'].to_list()[0]

balance_farming_f    = mu.flatten_internal_dict(balance_farming)
balance_traffic_f    = mu.flatten_internal_dict(balance_traffic)
balance_non_energy_f = mu.flatten_internal_dict(balance_non_energy)

# %%
# Display plots of energy use
plt.figure(figsize=(30, 5))
ax = plt.subplot(1, 3, 1)
ax.set_title('Kmetijstvo in gozdarstvo')
plt.suptitle("Poraba energetskih virov", fontsize=20)
plt.xticks(rotation=90)
plt.ylabel("Poraba energenta (TJ)")
plt.grid()
for key, value in balance_farming_f.items():
    if key != 'Energetski viri-SKUPAJ':
        plt.plot(years, value, label=key)
plt.legend()

ax = plt.subplot(1, 3, 2)
ax.set_title('Promet')
plt.xticks(rotation=90)
plt.ylabel("Poraba energenta (TJ)")
plt.grid()
for key, value in balance_traffic_f.items():
    if key != 'Energetski viri-SKUPAJ':
        plt.plot(years, value, label=key)
plt.legend()

ax = plt.subplot(1, 3, 3)
ax.set_title('Neenergetska raba')
plt.xticks(rotation=90)
plt.ylabel("Poraba energenta (TJ)")
plt.grid()
for key, value in balance_non_energy_f.items():
    if key != 'Energetski viri-SKUPAJ':
        plt.plot(years, value, label=key)
plt.legend();

# %% [markdown]
# Pri analizi porabe energentov v različnih sektorjih, smo po pričakovanjih opazili da kmetijstvo in gozdarstvo ter promet porabita največ naftnih proizvodov, kot so motorno gorivo in dizelsko gorivo, o katerih smo govorili že v prejšnjem vprašanju.
#
# Zanimiv je porast porabe geotermalne in sončne energije v kmetijstvu in gozdarstvu, ki se je začel leta 2009, sovpada pa z padcem porabe naftnih proizvodov. Predvidevamo, da je do tega prišlo zaradi globalne krize, in potrebe po osamosvojitvi oz. zmanjšanju odvisnosti od tujih virov.
#
# Poleg tega je zanimiva tudi majhna poraba obnovljivih virov v prometnem sektorju, ki se je začela leta 2007. To potrjuje tudi [European Environment Agency](https://www.eea.europa.eu/ims/use-of-renewable-energy-for), ki pravi, da je leta 2009 Renewable Energy Directive postavil tarče za države članice, da mora do leta 2020, vsaj 10% energentov porabljenih v transportu prihajati iz obnovljivih virov energije.
#
# Kar pa se tiče [neenergetskega sektorja](http://www.interenerstat.org/definitions/results.asp?id=168&Type=Flows), opazimo, da se uporabljajo le trdna goriva, naftni proizvodi in zemeljski plin. Zanimivo je, da je z leta 2009 na leto 2011 poraba zemeljskega plina vpadla skoraj na 0TJ, in da od takrat zelo počasi narašča. Prav tako je v tem časovnem obdobju rahlo upadla uporaba trdnih energentov in naftnih proizvodov. Predvidevamo, da je do tega prišlo zaradi takratne globalne krize, ki je vplivala na delovanja raznih tovarn, in pa napredkov na samem področju, ki so facilitirali uporabo drugih virov.

# %% [markdown]
# ##### 3.3.2 Analiza uvoza/izvoza naftnih proizvodov

# %%
oil_products = dict.fromkeys(['Domača proizvodnja', 'Uvoz', 'Izvoz', 'Spremembe zalog'])

for key in oil_products.keys():
    oil_products[key] = dict.fromkeys(balance.columns[2:])
    for year in balance.columns[2:]:
        oil_products[key][year] = balance[year][balance['OSKRBA IN PORABA'] == key][balance['ENERGETSKI VIR'] == 'Naftni proizvodi'].to_list()[0]
        
oil_products_f = mu.flatten_internal_dict(oil_products)
gozdarsgadsaaf Display plots of oil products
plt.figure(figsize=(20, 5))
plt.suptitle("Analiza naftnih proizvodov", fontsize=20)
plt.xticks(rotation=90)
plt.ylabel("Količina energenta (TJ)")
plt.grid()
for key, value in oil_products_f.items():
    plt.plot(years, value, label=key)
plt.legend();

# %%
print("Procentualna razlika v uvozu naftnih proizvodov med letom 2013 in 2016:", mu.get_percentage_diff(oil_products['Uvoz']['2016'], oil_products['Uvoz']['2013']))
print("Procentualna razlika v uvozu naftnih proizvodov med letom 2009 in 2012:", mu.get_percentage_diff(oil_products['Uvoz']['2012'], oil_products['Uvoz']['2009']))
# Out:
# Procentualna razlika v uvozu naftnih proizvodov med letom 2013 in 2016: 39.52614658123149
# Procentualna razlika v uvozu naftnih proizvodov med letom 2009 in 2012: 14.646269042086239

# %% [markdown]
# Iz prikazanega grafa smo opazili, da v Sloveniji nikoli nismo proizvajali naftnih proizvodov, kar je smiselno, saj nimamo naravnih rezursov za to. Prav tako smo opazili, da veliko več naftnih proizvodov uvozimo kot izvozimo. Zanimivo pa je, da uvoz naftnih proizvodov vztrajno narašča, od leta 2013 posebej pa narašča še hitreje, uvoz se je namreč od leta 2013 do leta 2016 spremenil za kar 39.5%. Po pričakovanjih pa opazimo tudi, da sta uvoz in izvoz iz leta 2019 na leto 2020 upadla. Porast uvozov potrjujejo tudi na [Banki slovenije, str. 2](https://bankaslovenije.blob.core.windows.net/publication-files/pb_2013_06.pdf), kjer pravijo, da se je uvoz blaga v prvem četrtletju 2013 zmanjšal le za 0.5% (tega ne moremo potrditi, saj nimamo četrtletnih podatkov), nato pa je narasel.

# %% [markdown]
# ##### 3.3.3 Ugotovitve
#
# Pri analizi energetske bilance smo se specifično osredotočili na analizo porabe energentov po nekaterih nam zanimivih sektorjih, in pa na analizo uvoza/izvoza in proizvodnje naftnih proizvodov. Za analizo naftnih proizvodov smo se odločili zato, ker so to najbolj uporabljani energenti v Sloveniji.
#
# Ko smo analizirali porabo energentov v sektorjih kmetijstva in gozdarstva, prometa in neenergetske rabe smo ugotovili, da so v kmetijstvu in gozdarstvu ter prometu najbolj uporabljani energenti naftni proizvodi, kar je smiselno saj vanje spadata motorno gorivo in dizelsko gorivo, o katerih pa smo govorili že pri prejšnjem vprašanju.
#
# Zanimiv je porast geotermalne in sončne energije v kmetijstvu in gozdarstvu leta 2009, ki sovpada z padcem porabe naftnih proizvodov, do česar predvidevamo, da je prišlo zaradi globalne ekonomske krize in potrebe po osamosvojitvi oz. zmanjšanju odvisnosti porabe od tujih virov.
#
# Zanimivo je, da je z leta 2009 na leto 2011 poraba zemeljskega plina v neenergetskem sektorju vpadla skoraj na 0TJ, in da od takrat zelo počasi narašča. Prav tako je v tem časovnem obdobju rahlo upadla uporaba trdnih energentov in naftnih proizvodov. Predvidevamo, da je do tega prišlo zaradi takratne globalne krize, ki je vplivala na delovanja raznih tovarn, in pa napredkov na samem področju, ki so facilitirali uporabo drugih virov.
#
# Pri analizi oskrbe z naftnimi proizvodi pa smo ugotovili, da jih uvozimo veliko več kot izvozimo, proizvajamo pa jih seveda ne. Tu je zanimiv porast v uvozu iz leta 2013 na leto 2016 (za 39.5%), kar potrjujejo tudi na [Banki slovenije, str. 2](https://bankaslovenije.blob.core.windows.net/publication-files/pb_2013_06.pdf), kjer pravijo, da se je uvoz blaga v prvem četrtletju 2013 zmanjšal le za 0.5% (tega ne moremo potrditi, saj nimamo četrtletnih podatkov), nato pa je narasel.

# %% [markdown]
# #### 3.4 Analiza porabe goriv po dejavnosti
#
# Pri tem podvprašanju smo analizirali porabo skozi čas glede na panogo. Ker določene panoge nimajo dovolj podatkov, smo jih izključili iz analize.

# %% [markdown]
# ##### 3.4.1 Priprava podatkov

# %%
# List of sectors to analyze (no subsectors included)
wider_sectors = ['A Kmetijstvo in lov, gozdarstvo, ribištvo', \
                 'B Rudarstvo', \
                 'C Predelovalne dejavnosti', \
                 'D Oskrba z električno energijo, plinom in paro', \
                 'E Oskrba z vodo, ravnanje z odplakami in odpadki, saniranje okolja', \
                 'F Gradbeništvo']

# Create dicts of energy sources and their usages for each sector
use_farming      = mu.init_dict_based_on_column(use, 'ENERGETSKI VIR')
use_mining       = mu.init_dict_based_on_column(use, 'ENERGETSKI VIR')
use_processing   = mu.init_dict_based_on_column(use, 'ENERGETSKI VIR')
use_energetics   = mu.init_dict_based_on_column(use, 'ENERGETSKI VIR')
use_water        = mu.init_dict_based_on_column(use, 'ENERGETSKI VIR')
use_construction = mu.init_dict_based_on_column(use, 'ENERGETSKI VIR')

# Loop through all energy sources
for key in use_farming.keys():
    # Init internal dict of years for each sector and energy source
    use_farming[key]      = dict.fromkeys(use.columns[2:])
    use_mining[key]       = dict.fromkeys(use.columns[2:])
    use_processing[key]   = dict.fromkeys(use.columns[2:])
    use_energetics[key]   = dict.fromkeys(use.columns[2:])
    use_water[key]        = dict.fromkeys(use.columns[2:])
    use_construction[key] = dict.fromkeys(use.columns[2:])
    # Fill internal dicts with values for each year
    for year in use.columns[2:]:
        use_farming[key][year]      = use[year][use['ENERGETSKI VIR'] == key][use['PODROČJA IN PODPODROČJA DEJAVNOSTI'] == wider_sectors[0]].to_list()[0]
        use_mining[key][year]       = use[year][use['ENERGETSKI VIR'] == key][use['PODROČJA IN PODPODROČJA DEJAVNOSTI'] == wider_sectors[1]].to_list()[0]
        use_processing[key][year]   = use[year][use['ENERGETSKI VIR'] == key][use['PODROČJA IN PODPODROČJA DEJAVNOSTI'] == wider_sectors[2]].to_list()[0]
        use_energetics[key][year]   = use[year][use['ENERGETSKI VIR'] == key][use['PODROČJA IN PODPODROČJA DEJAVNOSTI'] == wider_sectors[3]].to_list()[0]
        use_water[key][year]        = use[year][use['ENERGETSKI VIR'] == key][use['PODROČJA IN PODPODROČJA DEJAVNOSTI'] == wider_sectors[4]].to_list()[0]
        use_construction[key][year] = use[year][use['ENERGETSKI VIR'] == key][use['PODROČJA IN PODPODROČJA DEJAVNOSTI'] == wider_sectors[5]].to_list()[0]
    
# Flatten internal dicts    
use_farming_f      = mu.flatten_internal_dict(use_farming)
use_mining_f       = mu.flatten_internal_dict(use_mining)
use_processing_f   = mu.flatten_internal_dict(use_processing)
use_energetics_f   = mu.flatten_internal_dict(use_energetics)
use_water_f        = mu.flatten_internal_dict(use_water)
use_construction_f = mu.flatten_internal_dict(use_construction)

# %% [markdown]
# Ker smo iz podatkov ugotovili, da podatki za določena področja obstajajo šele od leta 2016/2017, smo se odločili, da tistih področji ni smiselno analizirati.

# %% [markdown]
# ##### 3.4.2 Prikaz podatkov in analiza

# %%
years = use.columns[2:]

# Display plots of energy use
plt.figure(figsize=(30, 5))
plt.suptitle('Analiza naftnih proizvodov', fontsize=20)
ax = plt.subplot(1, 3, 1)
ax.set_title(wider_sectors[1])
plt.xticks(rotation=90)
plt.ylabel('Količina energenta (TJ)')
plt.grid()
for key, value in use_mining_f.items():
    plt.plot(years, [float(v) if not pd.isna(v) else 0.0 for v in value], label=key)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.5), ncol=3)
print()

ax = plt.subplot(1, 3, 2)
ax.set_title(wider_sectors[2])
plt.xticks(rotation=90)
plt.ylabel('Količina energenta (TJ)')
plt.grid()
for key, value in use_processing_f.items():
    plt.plot(years, [float(v) if not pd.isna(v) else 0.0 for v in value], label=key)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.5), ncol=3)
print()

ax = plt.subplot(1, 3, 3)
ax.set_title(wider_sectors[5])
plt.xticks(rotation=90)
plt.ylabel('Količina energenta (TJ)')
plt.grid()
for key, value in use_construction_f.items():
    plt.plot(years, [float(v) if not pd.isna(v) else 0.0 for v in value], label=key)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.5), ncol=3);

# %%
print("Procentualna razlika v uporabi dizelskega goriva v gradbeništvu med letoma 2008 in 2011: ", \
      mu.get_percentage_diff(use_construction['Dizelsko gorivo']['2011'], use_construction['Dizelsko gorivo']['2008']))
# Out:
# Procentualna razlika v uporabi dizelskega goriva v gradbeništvu med letoma 2008 in 2011:  61.22778675282714

# %% [markdown]
# Pri analizi porabe energentov glede na gospodarska področja smo se osredotočili na specifično rudarstvo, predelovalne dejavnosti in gradbeništvo, saj za ostala področja nismo imeli dovolj podatkov za smiselno analizo. Opazili smo, da je v rudarstvu najpomembnejši energent električna energija, rahlo pa se uporabljajo tudi zemeljski plin, dizelsko gorivo in toplotna energija, zanimivo pa je, da se je leta 2015 prenehala uporaba utekočinjenenga naftnega plina.
#
# Pri predelovalnih dejavnostih sta najpomembnejša energenta električna energija in zemeljski plin, malo pa se uporabljajo tudi les in lesni odpadki ter toplotna energija, ostali energenti pa se uporabljajo v zanemarljivo majhnih količinah.
#
# Pri analizi gradbeništva smo opazili, da se najbolj uporablja dizelsko gorivo, uporaba katerega pa se je iz leta 2008 do leta 2011 zmanjšala za kar 61.22%, rahlo pa je narasla poraba zemeljskega plina, ki je leta 2013 padla na raven, pred letom 2011. Predvidevamo, da je do tako velikega padca prišlo zaradi globalne krize leta 2009, ki je najmočneje vplivala na trg nepremičnin, kar bi pomenilo veliko manj gradnje.

# %% [markdown]
# ##### 3.4.3 Ugotovitve
#
# Pri analizi porabe goriv po panogi smo najprej ugotovili, da smo za določene panoge (A Kmetijstvo in lov, gozdarstvo, ribištvo, D Oskrba z električno energijo, plinom in paro, E Oskrba z vodo, ravnanje z odplakami in odpadki, saniranje okolja) imeli premalo podatkov za dobro statistično analizo, zato smo se osredotočili za panoge Rudarstvo, Predelovalne dejavnosti in Gradbeništvo.
#
# Ugotovili smo, da je v rudarstvu najpomembnejši energent električna energija, v uporabi pa so tudi zemeljski plin, dizelsko gorivo in toplotna energija. Zanimivo je tudi dejstvo, da se je leta 2015 prenehala uporaba utekočinjenega naftnega plina.
#
# Za predelovalne dejavnosti smo ugotovili, da sta v uporabi najbolj električna energija in zemeljski plin, malo se uporabljajo tudi les in lesni odpadki ter toplotna energija, uporaba ostalih energentov pa je zanemarljiva.
#
# V gradbeništvu smo opazili, da je najpomembnejši energent dizelsko gorivo, uporaba katerega pa je močno upadla iz leta 2008 na leto 2011. Predvidevamo, da je do tega prišlo zaradi globalne ekonomske krize v letu 2009, ki je še posebej močno vplivala na nepremičninski sektor, kar pa je pustilo opazne posledice tudi na gradbeništvu, specifično, močno se je zmanjšalo število novogradenj, saj že obstoječe nepremičnine niso šle v promet. Zanimivo je, da se poraba dizelskega goriva od takrat v Sloveniji ni nikoli dvignila na ravni pred krizo, kar je lahko posledica krize, še en mogoč faktor pa je tudi razvoj bolj učinkovite gradbene opreme.
