# %% [markdown]
# # 4. Analiza oskrbe z električno energijo
#
# **Pri tem vprašanju nas je zanimala rast dejanske moči in proizvodnje energije glede na vir, uvoz in izvoz, količina izgub, vsebnost ogljika v oskrbi z energijo..**

# %% [markdown]
# #### 4.1 Pregled podatkov v potrebnih podatkovnih množicah
#
# Najprej smo pregledali podatke v podatkovnih množicah, ki smo jih uporabljali. To smo naredili z izpisom glave podatkovnega okvirja.

# %%
from reading import data_extraction as de
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import misc_utils as mu

energy_production = de.read('../data/Proizvodnja in dejanska moc v elektrarnah.csv')
energy_statistics = de.read('../data/Letna energetska statistika.csv')
renewable_sources = de.read('../data/Poraba obnovljivih virov energije in odpadkov.csv')

mu.display_side_by_side(energy_production.head(), energy_statistics.head(), renewable_sources.head(), 
                        titles=['Proizvodnja in dejanska moc v elektrarnah', 'Letna energetska statistika', 'Poraba obnovljivih virov energije in odpadkov'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2>Proizvodnja in dejanska moc v elektrarnah</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>POSTAVKA</th>
#       <th>1996 Elektrarne po glavni dejavnosti</th>
#       <th>1996 Samoproizvajalci</th>
#       <th>1996 Male zasebne hidroelektrarne</th>
#       <th>1996 Skupaj</th>
#       <th>1997 Elektrarne po glavni dejavnosti</th>
#       <th>1997 Samoproizvajalci</th>
#       <th>1997 Male zasebne hidroelektrarne</th>
#       <th>1997 Skupaj</th>
#       <th>1998 Elektrarne po glavni dejavnosti</th>
#       <th>1998 Samoproizvajalci</th>
#       <th>1998 Male zasebne hidroelektrarne</th>
#       <th>1998 Skupaj</th>
#       <th>1999 Elektrarne po glavni dejavnosti</th>
#       <th>1999 Samoproizvajalci</th>
#       <th>1999 Male zasebne hidroelektrarne</th>
#       <th>1999 Skupaj</th>
#       <th>2000 Elektrarne po glavni dejavnosti</th>
#       <th>2000 Samoproizvajalci</th>
#       <th>2000 Male zasebne hidroelektrarne</th>
#       <th>2000 Skupaj</th>
#       <th>2001 Elektrarne po glavni dejavnosti</th>
#       <th>2001 Samoproizvajalci</th>
#       <th>2001 Male zasebne hidroelektrarne</th>
#       <th>2001 Skupaj</th>
#       <th>2002 Elektrarne po glavni dejavnosti</th>
#       <th>2002 Samoproizvajalci</th>
#       <th>2002 Male zasebne hidroelektrarne</th>
#       <th>2002 Skupaj</th>
#       <th>2003 Elektrarne po glavni dejavnosti</th>
#       <th>2003 Samoproizvajalci</th>
#       <th>2003 Male zasebne hidroelektrarne</th>
#       <th>2003 Skupaj</th>
#       <th>2004 Elektrarne po glavni dejavnosti</th>
#       <th>2004 Samoproizvajalci</th>
#       <th>2004 Male zasebne hidroelektrarne</th>
#       <th>2004 Skupaj</th>
#       <th>2005 Elektrarne po glavni dejavnosti</th>
#       <th>2005 Samoproizvajalci</th>
#       <th>2005 Male zasebne hidroelektrarne</th>
#       <th>2005 Skupaj</th>
#       <th>2006 Elektrarne po glavni dejavnosti</th>
#       <th>2006 Samoproizvajalci</th>
#       <th>2006 Male zasebne hidroelektrarne</th>
#       <th>2006 Skupaj</th>
#       <th>2007 Elektrarne po glavni dejavnosti</th>
#       <th>2007 Samoproizvajalci</th>
#       <th>2007 Male zasebne hidroelektrarne</th>
#       <th>2007 Skupaj</th>
#       <th>2008 Elektrarne po glavni dejavnosti</th>
#       <th>2008 Samoproizvajalci</th>
#       <th>2008 Male zasebne hidroelektrarne</th>
#       <th>2008 Skupaj</th>
#       <th>2009 Elektrarne po glavni dejavnosti</th>
#       <th>2009 Samoproizvajalci</th>
#       <th>2009 Male zasebne hidroelektrarne</th>
#       <th>2009 Skupaj</th>
#       <th>2010 Elektrarne po glavni dejavnosti</th>
#       <th>2010 Samoproizvajalci</th>
#       <th>2010 Male zasebne hidroelektrarne</th>
#       <th>2010 Skupaj</th>
#       <th>2011 Elektrarne po glavni dejavnosti</th>
#       <th>2011 Samoproizvajalci</th>
#       <th>2011 Male zasebne hidroelektrarne</th>
#       <th>2011 Skupaj</th>
#       <th>2012 Elektrarne po glavni dejavnosti</th>
#       <th>2012 Samoproizvajalci</th>
#       <th>2012 Male zasebne hidroelektrarne</th>
#       <th>2012 Skupaj</th>
#       <th>2013 Elektrarne po glavni dejavnosti</th>
#       <th>2013 Samoproizvajalci</th>
#       <th>2013 Male zasebne hidroelektrarne</th>
#       <th>2013 Skupaj</th>
#       <th>2014 Elektrarne po glavni dejavnosti</th>
#       <th>2014 Samoproizvajalci</th>
#       <th>2014 Male zasebne hidroelektrarne</th>
#       <th>2014 Skupaj</th>
#       <th>2015 Elektrarne po glavni dejavnosti</th>
#       <th>2015 Samoproizvajalci</th>
#       <th>2015 Male zasebne hidroelektrarne</th>
#       <th>2015 Skupaj</th>
#       <th>2016 Elektrarne po glavni dejavnosti</th>
#       <th>2016 Samoproizvajalci</th>
#       <th>2016 Male zasebne hidroelektrarne</th>
#       <th>2016 Skupaj</th>
#       <th>2017 Elektrarne po glavni dejavnosti</th>
#       <th>2017 Samoproizvajalci</th>
#       <th>2017 Male zasebne hidroelektrarne</th>
#       <th>2017 Skupaj</th>
#       <th>2018 Elektrarne po glavni dejavnosti</th>
#       <th>2018 Samoproizvajalci</th>
#       <th>2018 Male zasebne hidroelektrarne</th>
#       <th>2018 Skupaj</th>
#       <th>2019 Elektrarne po glavni dejavnosti</th>
#       <th>2019 Samoproizvajalci</th>
#       <th>2019 Male zasebne hidroelektrarne</th>
#       <th>2019 Skupaj</th>
#       <th>2020 Elektrarne po glavni dejavnosti</th>
#       <th>2020 Samoproizvajalci</th>
#       <th>2020 Male zasebne hidroelektrarne</th>
#       <th>2020 Skupaj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Proizvodnja na generatorju-SKUPAJ (GWh)</td>
#       <td>12239.0</td>
#       <td>410.0</td>
#       <td>88.0</td>
#       <td>12737.0</td>
#       <td>12687.0</td>
#       <td>418.0</td>
#       <td>73.0</td>
#       <td>13178.0</td>
#       <td>13175.0</td>
#       <td>431.0</td>
#       <td>99.0</td>
#       <td>13705.0</td>
#       <td>12642.0</td>
#       <td>526.0</td>
#       <td>93.0</td>
#       <td>13261.0</td>
#       <td>12988.0</td>
#       <td>546.0</td>
#       <td>90.0</td>
#       <td>13624.0</td>
#       <td>13834.0</td>
#       <td>524.0</td>
#       <td>109.0</td>
#       <td>14467.0</td>
#       <td>14109.0</td>
#       <td>396.0</td>
#       <td>94.0</td>
#       <td>14599.0</td>
#       <td>13355.0</td>
#       <td>386.0</td>
#       <td>79.0</td>
#       <td>13820.0</td>
#       <td>14664.0</td>
#       <td>457.0</td>
#       <td>151.0</td>
#       <td>15272.0</td>
#       <td>14529.0</td>
#       <td>432.0</td>
#       <td>156.0</td>
#       <td>15117.0</td>
#       <td>14549.0</td>
#       <td>382.0</td>
#       <td>184.0</td>
#       <td>15115.0</td>
#       <td>14499.0</td>
#       <td>367.0</td>
#       <td>177.0</td>
#       <td>15043.0</td>
#       <td>15859.0</td>
#       <td>359.0</td>
#       <td>180.0</td>
#       <td>16398.0</td>
#       <td>15935.0</td>
#       <td>402.0</td>
#       <td>66.0</td>
#       <td>16403.0</td>
#       <td>15969.0</td>
#       <td>403.0</td>
#       <td>68.0</td>
#       <td>16440.0</td>
#       <td>15622.0</td>
#       <td>391.0</td>
#       <td>46.0</td>
#       <td>16059.0</td>
#       <td>15202.0</td>
#       <td>481.0</td>
#       <td>53.0</td>
#       <td>15736.0</td>
#       <td>15481.0</td>
#       <td>547.0</td>
#       <td>75.0</td>
#       <td>16103.0</td>
#       <td>16687.0</td>
#       <td>632.0</td>
#       <td>118.0</td>
#       <td>17437.0</td>
#       <td>14412.0</td>
#       <td>611.0</td>
#       <td>77.0</td>
#       <td>15100.0</td>
#       <td>15746.0</td>
#       <td>614.0</td>
#       <td>140.0</td>
#       <td>16500.0</td>
#       <td>15594.811</td>
#       <td>615.147</td>
#       <td>116.267</td>
#       <td>16326.225</td>
#       <td>15603.285</td>
#       <td>588.450</td>
#       <td>135.199</td>
#       <td>16326.935</td>
#       <td>15330.547</td>
#       <td>638.152</td>
#       <td>130.865</td>
#       <td>16099.564</td>
#       <td>16340.023</td>
#       <td>715.963</td>
#       <td>134.712</td>
#       <td>17190.698</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Proizvodnja na generatorju-hidroelektrarne-SKUPAJ (GWh)</td>
#       <td>3479.0</td>
#       <td>100.0</td>
#       <td>88.0</td>
#       <td>3667.0</td>
#       <td>2945.0</td>
#       <td>74.0</td>
#       <td>73.0</td>
#       <td>3092.0</td>
#       <td>3263.0</td>
#       <td>87.0</td>
#       <td>99.0</td>
#       <td>3449.0</td>
#       <td>3541.0</td>
#       <td>105.0</td>
#       <td>93.0</td>
#       <td>3739.0</td>
#       <td>3648.0</td>
#       <td>96.0</td>
#       <td>90.0</td>
#       <td>3834.0</td>
#       <td>3587.0</td>
#       <td>100.0</td>
#       <td>109.0</td>
#       <td>3796.0</td>
#       <td>3148.0</td>
#       <td>71.0</td>
#       <td>94.0</td>
#       <td>3313.0</td>
#       <td>2822.0</td>
#       <td>57.0</td>
#       <td>79.0</td>
#       <td>2958.0</td>
#       <td>3856.0</td>
#       <td>87.0</td>
#       <td>151.0</td>
#       <td>4094.0</td>
#       <td>3236.0</td>
#       <td>68.0</td>
#       <td>156.0</td>
#       <td>3460.0</td>
#       <td>3342.0</td>
#       <td>65.0</td>
#       <td>184.0</td>
#       <td>3591.0</td>
#       <td>3024.0</td>
#       <td>65.0</td>
#       <td>177.0</td>
#       <td>3266.0</td>
#       <td>3758.0</td>
#       <td>80.0</td>
#       <td>180.0</td>
#       <td>4018.0</td>
#       <td>4550.0</td>
#       <td>98.0</td>
#       <td>66.0</td>
#       <td>4714.0<

# %% [markdown]
# Kot lahko vidimo, sta podatkovni množici [Proizvodnja in dejanska moc v elektrarnah.csv](../data/Proizvodnja%20in%20dejanska%20moc%20v%20elektrarnah.csv) in [Poraba obnovljivih virov energije in odpadkov.csv](../data/Poraba%20obnovljivih%20virov%20energije%20in%20odpadkov.csv) v precej neuporabni obliki, saj želimo, da so v stolpcih samo leta, ostali atributi pa so v posebnem stolpcu. Podatkovna množica [Letna energetska statistika.csv](../data/Letna%20energetska%20statistika.csv) pa je v uporabni obliki, tako da jo ni bilo potrebno preoblikovati. Tak format želimo zato, da lahko podatke obdelujemo po časovnih obdobjih, brez da bi bilo potrebno manipuliranje imen stolpcev.

# %% [markdown]
# #### 4.2 Preoblikovanje podatkovnih množic
#
# Najprej smo se lotili preoblikovanja podatkovnih množic v format, ki je bolj primeren za našo uporabo.

# %%
# Get unique values of energy sources and years
production_activity = list(dict.fromkeys([' '.join(col.split()[1:]) for col in energy_production.columns[1:]]))
production_years    = sorted(list(set([col.split()[0] for col in energy_production.columns[1:]])))

# Create new dataframe
production = pd.DataFrame()

# Add needed columns to dataframe
production.insert(0, 'POSTAVKA', '')
production.insert(1, 'DEJAVNOST', '')
count = 2
for year in production_years:
    production.insert(count, year, np.nan)
    count += 1

## Fill dataframe with data
# Add first two columns
for oip in energy_production['POSTAVKA']:
    for activity in production_activity:
        production.loc[len(production.index)] = [oip, activity] + [np.nan] * len(production_years)

# Add values from Energetska bilanca.csv
for col in energy_production.columns[1:]:
    # Extract year and energy source from column name
    year   = col.split()[0]
    source = ' '.join(col.split()[1:])
    # Loop through all rows in dataframe and add value to appropriate cell
    for index, row in energy_production.iterrows():
        if row[col] != '-' and row[col] != 'N':
            production.loc[(production['POSTAVKA'] == row['POSTAVKA']) & (production['DEJAVNOST'] == source), year] = row[col]

energy_production = production

mu.display_side_by_side(energy_production.head())
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>POSTAVKA</th>
#       <th>DEJAVNOST</th>
#       <th>1996</th>
#       <th>1997</th>
#       <th>1998</th>
#       <th>1999</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Proizvodnja na generatorju-SKUPAJ (GWh)</td>
#       <td>Elektrarne po glavni dejavnosti</td>
#       <td>12239.0</td>
#       <td>12687.0</td>
#       <td>13175.0</td>
#       <td>12642.0</td>
#       <td>12988.0</td>
#       <td>13834.0</td>
#       <td>14109.0</td>
#       <td>13355.0</td>
#       <td>14664.0</td>
#       <td>14529.0</td>
#       <td>14549.0</td>
#       <td>14499.0</td>
#       <td>15859.0</td>
#       <td>15935.0</td>
#       <td>15969.0</td>
#       <td>15622.0</td>
#       <td>15202.0</td>
#       <td>15481.0</td>
#       <td>16687.0</td>
#       <td>14412.0</td>
#       <td>15746.0</td>
#       <td>15594.811</td>
#       <td>15603.285</td>
#       <td>15330.547</td>
#       <td>16340.023</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Proizvodnja na generatorju-SKUPAJ (GWh)</td>
#       <td>Samoproizvajalci</td>
#       <td>410.0</td>
#       <td>418.0</td>
#       <td>431.0</td>
#       <td>526.0</td>
#       <td>546.0</td>
#       <td>524.0</td>
#       <td>396.0</td>
#       <td>386.0</td>
#       <td>457.0</td>
#       <td>432.0</td>
#       <td>382.0</td>
#       <td>367.0</td>
#       <td>359.0</td>
#       <td>402.0</td>
#       <td>403.0</td>
#       <td>391.0</td>
#       <td>481.0</td>
#       <td>547.0</td>
#       <td>632.0</td>
#       <td>611.0</td>
#       <td>614.0</td>
#       <td>615.147</td>
#       <td>588.450</td>
#       <td>638.152</td>
#       <td>715.963</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Proizvodnja na generatorju-SKUPAJ (GWh)</td>
#       <td>Male zasebne hidroelektrarne</td>
#       <td>88.0</td>
#       <td>73.0</td>
#       <td>99.0</td>
#       <td>93.0</td>
#       <td>90.0</td>
#       <td>109.0</td>
#       <td>94.0</td>
#       <td>79.0</td>
#       <td>151.0</td>
#       <td>156.0</td>
#       <td>184.0</td>
#       <td>177.0</td>
#       <td>180.0</td>
#       <td>66.0</td>
#       <td>68.0</td>
#       <td>46.0</td>
#       <td>53.0</td>
#       <td>75.0</td>
#       <td>118.0</td>
#       <td>77.0</td>
#       <td>140.0</td>
#       <td>116.267</td>
#       <td>135.199</td>
#       <td>130.865</td>
#       <td>134.712</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Proizvodnja na generatorju-SKUPAJ (GWh)</td>
#       <td>Skupaj</td>
#       <td>12737.0</td>
#       <td>13178.0</td>
#       <td>13705.0</td>
#       <td>13261.0</td>
#       <td>13624.0</td>
#       <td>14467.0</td>
#       <td>14599.0</td>
#       <td>13820.0</td>
#       <td>15272.0</td>
#       <td>15117.0</td>
#       <td>15115.0</td>
#       <td>15043.0</td>
#       <td>16398.0</td>
#       <td>16403.0</td>
#       <td>16440.0</td>
#       <td>16059.0</td>
#       <td>15736.0</td>
#       <td>16103.0</td>
#       <td>17437.0</td>
#       <td>15100.0</td>
#       <td>16500.0</td>
#       <td>16326.225</td>
#       <td>16326.935</td>
#       <td>16099.564</td>
#       <td>17190.698</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Proizvodnja na generatorju-hidroelektrarne-SKUPAJ (GWh)</td>
#       <td>Elektrarne po glavni dejavnosti</td>
#       <td>3479.0</td>
#       <td>2945.0</td>
#       <td>3263.0</td>
#       <td>3541.0</td>
#       <td>3648.0</td>
#       <td>3587.0</td>
#       <td>3148.0</td>
#       <td>2822.0</td>
#       <td>3856.0</td>
#       <td>3236.0</td>
#       <td>3342.0</td>
#       <td>3024.0</td>
#       <td>3758.0</td>
#       <td>4550.0</td>
#       <td>4537.0</td>
#       <td>3581.0</td>
#       <td>3961.0</td>
#       <td>4757.0</td>
#       <td>6138.0</td>
#       <td>3937.0</td>
#       <td>4555.0</td>
#       <td>3951.688</td>
#       <td>4671.679</td>
#       <td>4469.858</td>
#       <td>5006.958</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
# Get unique values of energy sources and years
renewable_activity = list(dict.fromkeys([' '.join(col.split()[1:]) for col in renewable_sources.columns[1:]]))
renewable_years    = sorted(list(set([col.split()[0] for col in renewable_sources.columns[1:]])))

# Create new dataframe
renewable = pd.DataFrame()

# Add needed columns to dataframe
renewable.insert(0, 'ENERGETSKI VIR', '')
renewable.insert(1, 'SKUPINA', '')
count = 2
for year in renewable_years:
    renewable.insert(count, year, np.nan)
    count += 1

## Fill dataframe with data
# Add first two columns
for oip in renewable_sources['ENERGETSKI VIR']:
    for activity in renewable_activity:
        renewable.loc[len(renewable.index)] = [oip, activity] + [np.nan] * len(renewable_years)

# Add values from Energetska bilanca.csv
for col in renewable_sources.columns[1:]:
    # Extract year and energy source from column name
    year   = col.split()[0]
    source = ' '.join(col.split()[1:])
    # Loop through all rows in dataframe and add value to appropriate cell
    for index, row in renewable_sources.iterrows():
        if row[col] != '-' and row[col] != 'N':
            renewable.loc[(renewable['ENERGETSKI VIR'] == row['ENERGETSKI VIR']) & (renewable['SKUPINA'] == source), year] = row[col]

renewable_sources = renewable

mu.display_side_by_side(renewable_sources.head())
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ENERGETSKI VIR</th>
#       <th>SKUPINA</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Geotermalna in toplota iz okolice (TJ)</td>
#       <td>Transformacija</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>83.000</td>
#       <td>72.000</td>
#       <td>84.000</td>
#       <td>78.000</td>
#       <td>62.000</td>
#       <td>65.000</td>
#       <td>46.000</td>
#       <td>45.094</td>
#       <td>39.083</td>
#       <td>38.830</td>
#       <td>37.998</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Geotermalna in toplota iz okolice (TJ)</td>
#       <td>Končna raba</td>
#       <td>33.353</td>
#       <td>45.069</td>
#       <td>67.003</td>
#       <td>99.717</td>
#       <td>129.276</td>
#       <td>164.069</td>
#       <td>223.560</td>
#       <td>274.755</td>
#       <td>1092.690</td>
#       <td>1182.630</td>
#       <td>1240.208</td>
#       <td>1407.109</td>
#       <td>1494.561</td>
#       <td>1666.442</td>
#       <td>1913.102</td>
#       <td>2099.319</td>
#       <td>2156.505</td>
#       <td>2241.138</td>
#       <td>2561.053</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Geotermalna in toplota iz okolice (TJ)</td>
#       <td>Skupaj</td>
#       <td>33.353</td>
#       <td>45.069</td>
#       <td>67.003</td>
#       <td>99.717</td>
#       <td>129.276</td>
#       <td>164.069</td>
#       <td>223.560</td>
#       <td>274.755</td>
#       <td>1175.700</td>
#       <td>1254.600</td>
#       <td>1324.200</td>
#       <td>1485.100</td>
#       <td>1556.600</td>
#       <td>1731.400</td>
#       <td>1959.100</td>
#       <td>2144.413</td>
#       <td>2195.588</td>
#       <td>2279.968</td>
#       <td>2599.051</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Solarna termična (TJ)</td>
#       <td>Transformacija</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Solarna termična (TJ)</td>
#       <td>Končna raba</td>
#       <td>200.490</td>
#       <td>196.375</td>
#       <td>196.340</td>
#       <td>205.966</td>
#       <td>220.577</td>
#       <td>242.982</td>
#       <td>259.425</td>
#       <td>321.352</td>
#       <td>344.473</td>
#       <td>372.603</td>
#       <td>409.998</td>
#       <td>426.000</td>
#       <td>429.169</td>
#       <td>434.918</td>
#       <td>439.895</td>
#       <td>441.451</td>
#       <td>442.896</td>
#       <td>443.298</td>
#       <td>430.445</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# Podatkovne množice smo preoblikovali tako, da smo ustvarili nova podatkovna okvirja, katerima smo pripisali potrebne stolpce, nato pa smo v ustrezne celice vstavili vrednost iz originalnih podatkovnih množic. Tako smo dobili podatkovne okvirje, s katerimi je lažje delati (dostopati do vrednosti, analizirati vrednosti v času, itd.).

# %% [markdown]
# #### 4.3 Analiza obnovljivih virov energije
#
# Pri tem podvprašanju smo analizirali porabo obnovljivih virov in odpadkov v Sloveniji skozi čas.

# %%
# Create dictionary with energy sources
final_usage = mu.init_dict_based_on_column(renewable_sources, 'ENERGETSKI VIR')

# Fill dictionary
for year in renewable_sources.columns[2:]:
    for key in final_usage.keys():
        final_usage[key][year] = renewable_sources[year][renewable_sources['ENERGETSKI VIR'] == key][renewable_sources['SKUPINA'] == 'Skupaj'].to_list()[0]

# Flatten internal dict
final_usage_f = mu.flatten_internal_dict(final_usage)

years = renewable_sources.columns[2:]

print('Povprečna poraba lesa in druge trdne biomase skozi leta:', np.mean(final_usage_f['Les in druga trdna biomasa (TJ)']))

# Plot different energy sources
plt.figure(figsize=(20, 5))
plt.suptitle("Poraba obnovljivih virov in odpadkov", fontsize=20)
plt.xticks(rotation=90)
plt.ylabel("Poraba energetskega vira (TJ)")
plt.grid()
for key, value in final_usage_f.items():
    plt.plot(years, value, label=key)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5));
# Out:
# Povprečna poraba lesa in druge trdne biomase skozi leta: 25948.23289473684

# %% [markdown]
# Kot lahko vidimo z grafa, v Sloveniji porabimo največ lesa in druge trdne biomase, od leta 2002 do 2020 povprečno kar 25948 TJ. To je smiselno, saj je Slovenija država, ki je bogata z gozdovi. Kar se tiče ostalih obnovljivih virov, opazimo da se jih uporablja veliko manj, leta 2017 pa se je zvišala poraba biodizla.

# %% [markdown]
# ##### 4.3.1 Analiza porabe solarne in geotermalne energije

# %%
sources_to_analyze = ['Geotermalna in toplota iz okolice (TJ)', 'Solarna termična (TJ)']

# Plot different energy sources
plt.figure(figsize=(20, 5))
plt.suptitle("Poraba solarne in geotermalne energije", fontsize=20)
plt.xticks(rotation=90)
plt.ylabel("Poraba energetskega vira (TJ)")
plt.grid()
for key, value in final_usage_f.items():
    if key in sources_to_analyze:
        plt.plot(years, value, label=key)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
print('Procentualna razlika v porabi geotermalne energije v letih 2010 in 2009:', \
    mu.get_percentage_diff(final_usage['Geotermalna in toplota iz okolice (TJ)']['2010'], final_usage['Geotermalna in toplota iz okolice (TJ)']['2009']))
print('Koeficient rasti porabe sončne energije med leti 2009 in 2012:', \
    (final_usage['Solarna termična (TJ)']['2012'] - final_usage['Solarna termična (TJ)']['2009']) / final_usage['Solarna termična (TJ)']['2009'])
# Out:
# Procentualna razlika v porabi geotermalne energije v letih 2010 in 2009: 327.9085003002675
# Koeficient rasti porabe sončne energije med leti 2009 in 2012: 0.2758532699345267

# %% [markdown]
# Kot lahko vidimo z grafa, je z leta 2009 na leto 2010 poraba Geotermalne energije močno poskočila (za približno 330%), kar potrjuje tudi [Direktorat za energijo, str. 30](http://www.energetika-portal.si/fileadmin/dokumenti/publikacije/energija_slo/evs_2009.pdf). Predivedvamo, da je do tega prišlo, ker je bil v prejšnjih letih sprejet Zakon o spremembah in dopolnitvah  Energetskega zakona, katerega glavne spremembe se nanašajo specifično na ureditev podpor kvalificiranim proizvajalcem obnovljivih virov energije.
#
# Poraba Solarne energije pa je skozi leta naraščala zelo počasi, sicer malo bolj med leti 2009 in 2012 (koeficient rasti 0.276), leta 2020 pa je poraba celo rahlo upadla.

# %% [markdown]
# ##### 4.3.3 Ugotovitve

# %% [markdown]
# #### 4.4 Analiza proizvodnje in dejanske moči na elektrarnah
#
# Pri tem podvprašanju smo analizirali proizvodnjo (proizvodnja na pragu, proizvodnja na generatorju, lastna raba) in dejanske moči na elektrarnah.

# %% [markdown]
# ##### 4.4.1

# %% [markdown]
# ##### 4.4.2

# %% [markdown]
# ##### 4.4.3 Ugotovitve
